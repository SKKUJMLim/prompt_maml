# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# # ANIL vs Meta prompt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(data=[prompt_data["accuracy"], maml_data["accuracy"]], palette="Set2")
plt.xticks([0, 1], ["Ours (Prompt)", "MAML"])
plt.ylabel("Accuracy")
plt.title("Accuracy Distribution Across Tasks")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=[prompt_data["accuracy"], maml_data["accuracy"]], palette="Set2")
plt.xticks([0, 1], ["Ours (Prompt)", "MAML"])
plt.ylabel("Accuracy")
plt.title("Accuracy Distribution Across Tasks (Violin)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # meta-learned visual prompt

# %%
file_path = '../MAML_Prompt_padding_5way_5shot_filter128_miniImagenet/MAML_Prompt_padding_5way_5shot_filter128_miniImagenet_per_task_acc.csv'
Prompt_data = pd.read_csv(file_path)

# %%
plt.figure(figsize=(12, 6))
plt.plot(Prompt_data.index, Prompt_data["accuracy"], marker='o', linestyle='-', label="Accuracy")
plt.title("Accuracy Trend Across All Tasks (Prompt_data)", fontsize=14)
plt.xlabel("Index of tasks", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # MAML

# %%
# Load the uploaded CSV file to examine its structure
file_path = '../MAML_5way_5shot_filter64_miniImagenet/MAML_5way_5shot_filter64_miniImagenet_per_task_acc.csv'
MAML_data = pd.read_csv(file_path)

# %%
plt.figure(figsize=(12, 6))
plt.plot(MAML_data.index, MAML_data["accuracy"], marker='o', linestyle='-', label="Accuracy")
plt.title("Accuracy Trend Across All Tasks (MAML)", fontsize=14)
plt.xlabel("Index of tasks", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # ANIL

# %%
# Load the uploaded CSV file to examine its structure
file_path = '../ANIL_5way_5shot_filter64_miniImagenet/ANIL_5way_5shot_filter64_miniImagenet_per_task_acc.csv'
data = pd.read_csv(file_path)

# %%
plt.figure(figsize=(12, 6))
plt.plot(MAML_data.index, MAML_data["accuracy"], marker='o', linestyle='-', label="Accuracy")
plt.title("Accuracy Trend Across All Tasks (ANIL)", fontsize=14)
plt.xlabel("Index of tasks", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
file_path = '../MAML_Prompt_arbiter_5way_5shot_filter64_miniImagenet/MAML_Prompt_arbiter_5way_5shot_filter64_miniImagenet_per_task_acc.csv'
Arbiter_data = pd.read_csv(file_path)

# %%
plt.figure(figsize=(12, 6))
plt.plot(Arbiter_data.index, Arbiter_data["accuracy"], marker='o', linestyle='-', label="Accuracy")
plt.title("Accuracy Trend Across All Tasks (Prompt Generator)", fontsize=14)
plt.xlabel("Index of tasks", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()
