# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data from the table
sizes = [10, 20, 30, 40, 50, 60, 70, 84]
maml = [65.33, 65.33, 65.33, 65.33, 65.33, 65.33, 65.33, 65.33]
anil = [66.9, 66.9, 66.9, 66.9, 66.9, 66.9, 66.9, 66.9]
padding = [66.04, 63.86, 60.60, 58.79, 58.79, 58.79, 58.79, 58.79]
fixed_patch = [66.81, 66.94, 66.42, 66.00, 64.14, 62.71, 59.95, 58.89]
random_patch = [66.04, 66.94, 66.42, 66.00, 64.14, 62.71, 59.95, 58.89]

# Plotting the data without error bars
plt.figure(figsize=(10, 6))
plt.plot(sizes, maml, '-r', label='MAML', color='blue')
plt.plot(sizes, anil, '-g', label='ANIL', color='green')
plt.plot(sizes, padding, '-o', label='Padding', color='orange')
plt.plot(sizes, fixed_patch, '-s', label='Fixed Patch', color='purple')
plt.plot(sizes, random_patch, '-^', label='Random Patch', color='brown')

# Adding labels, legend, and title
plt.xlabel('Size', fontsize=12)
plt.ylabel('Performance', fontsize=12)
plt.title('Performance Comparison Across Initialization Methods', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.xticks(sizes)

# Show the plot
plt.show()
# Out:
# C:\Users\JM\anaconda3\envs\maml\lib\site-packages\ipykernel_launcher.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-r" (-> color='r'). The keyword argument will take precedence.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\JM\anaconda3\envs\maml\lib\site-packages\ipykernel_launcher.py:12: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-g" (-> color='g'). The keyword argument will take precedence.
#   if sys.path[0] == "":
